# %% [markdown]
# <a href="https://colab.research.google.com/github/Svbarawkar/LGM_Internship/blob/main/Task1_LGM_Snehal_Barawkar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Snehal Barawkar**

# %% [markdown]
# # **LGMVIP | Data Science**

# %% [markdown]
# # **Beginner Level Task**

# %% [markdown]
# # **Task 1: Image To Pencil Sketch with Python**

# %% [markdown]
# # Import Modules

# %%
from google.colab.patches import cv2_imshow

# %% [markdown]
# The following command can be used to read image using OpenCV

# %%
import cv2

# %%
img = cv2.imread("123.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=509x339 at 0x7F0868C06810>

# %% [markdown]
# # **Convert to Grey Image**
#
#
#
#
# Using cvtColor function of OpenCV

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=509x339 at 0x7F086A507C50>

# %%
img_invert = cv2.bitwise_not(img_gray)

# %%
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=509x339 at 0x7F0868BA2550>

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21,21), sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=509x339 at 0x7F0868C176D0>

# %%
def dodgeV2(x, y):
  return cv2.divide(x, 255 - y, scale=256)

# %% [markdown]
# ## **Final Image**

# %%
final_img= dodgeV2(img_gray , img_smoothing)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=509x339 at 0x7F0868BFFE50>

# %% [markdown]
# ## **Thank You...!!**
